# %%
from datasets import load_dataset

# Load CIFAR-10 dataset from Hugging Face datasets
dataset = load_dataset("cifar10")

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['img', 'label'],
#         num_rows: 50000
#     })
#     test: Dataset({
#         features: ['img', 'label'],
#         num_rows: 10000
#     })
# })

# %%
print(dataset['train'])
# Out:
# Dataset({
#     features: ['img', 'label'],
#     num_rows: 50000
# })

# %%
print(dataset['train'][0])
# Out:
# {'img': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32 at 0x7FF71C2409A0>, 'label': 0}

# %% [markdown]
# img  - PIL image 32x32
# label - int

# %%
train_dataset = dataset["train"].shuffle(seed=42).select(range(500))  # Select 500 examples for training
test_dataset = dataset["test"].shuffle(seed=42).select(range(500))  # Select 500 examples for testing

# %%
train_dataset[0]
# Out:
# {'img': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=32x32>,
#  'label': 1}

# %%
from transformers import AutoImageProcessor
image_processor = AutoImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')

# %%
examples= train_dataset[0]
transformed = image_processor(examples['img'], return_tensors='pt')
print(transformed["pixel_values"].shape)
# Out:
# torch.Size([1, 3, 224, 224])

# %%
# def transform(examples):
#     transformed = image_processor(examples['img'], return_tensors='pt')
#     # transformed['labels'] = examples['label']
#     return transformed

# %%
def transform(example_batch):
    inputs = image_processor([x for x in example_batch['img']], return_tensors='pt')
    inputs['labels'] = example_batch['label']
    return inputs

# %%
# transformed_dataset = dataset.map(transform)
train_dataset = train_dataset.with_transform(transform)
test_dataset = test_dataset.with_transform(transform)

# %%
train_dataset[0:2]
# Out:
# {'pixel_values': tensor([[[[-0.7490, -0.7490, -0.7490,  ...,  0.2941,  0.2941,  0.2941],
#           [-0.7490, -0.7490, -0.7490,  ...,  0.2941,  0.2941,  0.2941],
#           [-0.7490, -0.7490, -0.7490,  ...,  0.2941,  0.2941,  0.2941],
#           ...,
#           [-0.5451, -0.5451, -0.5451,  ...,  0.0196,  0.0196,  0.0196],
#           [-0.5451, -0.5451, -0.5451,  ...,  0.0196,  0.0196,  0.0196],
#           [-0.5451, -0.5451, -0.5451,  ...,  0.0196,  0.0196,  0.0196]],
#
#          [[-0.7804, -0.7804, -0.7804,  ...,  0.1529,  0.1529,  0.1529],
#           [-0.7804, -0.7804, -0.7804,  ...,  0.1529,  0.1529,  0.1529],
#           [-0.7804, -0.7804, -0.7804,  ...,  0.1529,  0.1529,  0.1529],
#           ...,
#           [-0.6471, -0.6471, -0.6471,  ..., -0.1451, -0.1451, -0.1451],
#           [-0.6471, -0.6471, -0.6471,  ..., -0.1451, -0.1451, -0.1451],
#           [-0.6471, -0.6471, -0.6471,  ..., -0.1451, -0.1451, -0.1451]],
#
#          [[-0.8039, -0.8039, -0.8039,  ..., -0.3333, -0.3333, -0.3333],
#           [-0.8039, -0.8039, -0.8039,  ..., -0.3333, -0.3333, -0.3333],
#           [-0.8039, -0.8039, -0.8039,  ..., -0.3333, -0.3333, -0.3333],
#           ...,
#           [-0.7412, -0.7412, -0.7412,  ..., -0.3490, -0.3490, -0.3490],
#           [-0.7412, -0.7412, -0.7412,  ..., -0.3490, -0.3490, -0.3490],
#           [-0.7412, -0.7412, -0.7412,  ..., -0.3490, -0.3490, -0.3490]]],
#
#
#         [[[-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           ...,
#           [ 0.6000,  0.6000,  0.6000,  ..., -0.4902, -0.4902, -0.4902],
#           [ 0.6000,  0.6000,  0.6000,  ..., -0.4902, -0.4902, -0.4902],
#           [ 0.6000,  0.6000,  0.6000,  ..., -0.4902, -0.4902, -0.4902]],
#
#          [[-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           ...,
#           [-0.1451, -0.1451, -0.1451,  ..., -0.8039, -0.8039, -0.8039],
#           [-0.1451, -0.1451, -0.1451,  ..., -0.8039, -0.8039, -0.8039],
#           [-0.1451, -0.1451, -0.1451,  ..., -0.8039, -0.8039, -0.8039]],
#
#          [[-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           [-0.9922, -0.9922, -0.9922,  ..., -0.9922, -0.9922, -0.9922],
#           ...,
#           [-0.3882, -0.3882, -0.3882,  ..., -0.8902, -0.8902, -0.8902],
#           [-0.3882, -0.3882, -0.3882,  ..., -0.8902, -0.8902, -0.8902],
#           [-0.3882, -0.3882, -0.3882,  ..., -0.8902, -0.8902, -0.8902]]]]), 'labels': [1, 2]}

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=8)

# %%
for batch in train_loader:
    for p in batch['pixel_values']:
        print(p)
        print(p.shape)
        print('---------')
    for l in batch["labels"]:
        print(l)
        print("-------")
    
    inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
    print(inputs)
    print("Inputs -------")
    
    print(inputs['pixel_values'].shape)
    break
# Out:
# tensor([[[-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#          [-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#          [-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#          ...,
#          [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333],
#          [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333],
#          [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333]],
#
#         [[-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#          [-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#          [-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#          ...,
#          [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196],
#          [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196],
#          [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196]],
#
#         [[-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#          [-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#          [-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#          ...,
#          [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843],
#          [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843],
#          [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#          ...,
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529]],
#
#         [[ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#          ...,
#          [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588],
#          [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588],
#          [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588]],
#
#         [[ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#          [ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#          ...,
#          [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824],
#          [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824],
#          [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#          ...,
#          [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333],
#          [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333],
#          [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333]],
#
#         [[-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#          ...,
#          [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647],
#          [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647],
#          [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647]],
#
#         [[-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#          ...,
#          [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647],
#          [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647],
#          [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[ 0.2549,  0.2549,  0.2549,  ..., -0.2863, -0.2863, -0.2863],
#          [ 0.2549,  0.2549,  0.2549,  ..., -0.2863, -0.2863, -0.2863],
#          [ 0.2549,  0.2549,  0.2549,  ..., -0.2863, -0.2863, -0.2863],
#          ...,
#          [-0.1451, -0.1451, -0.1451,  ..., -0.1686, -0.1686, -0.1686],
#          [-0.1451, -0.1451, -0.1451,  ..., -0.1686, -0.1686, -0.1686],
#          [-0.1451, -0.1451, -0.1451,  ..., -0.1686, -0.1686, -0.1686]],
#
#         [[ 0.3569,  0.3569,  0.3569,  ..., -0.3412, -0.3412, -0.3412],
#          [ 0.3569,  0.3569,  0.3569,  ..., -0.3412, -0.3412, -0.3412],
#          [ 0.3569,  0.3569,  0.3569,  ..., -0.3412, -0.3412, -0.3412],
#          ...,
#          [-0.1216, -0.1216, -0.1216,  ..., -0.1137, -0.1137, -0.1137],
#          [-0.1216, -0.1216, -0.1216,  ..., -0.1137, -0.1137, -0.1137],
#          [-0.1216, -0.1216, -0.1216,  ..., -0.1137, -0.1137, -0.1137]],
#
#         [[ 0.2235,  0.2235,  0.2235,  ..., -0.2000, -0.2000, -0.2000],
#          [ 0.2235,  0.2235,  0.2235,  ..., -0.2000, -0.2000, -0.2000],
#          [ 0.2235,  0.2235,  0.2235,  ..., -0.2000, -0.2000, -0.2000],
#          ...,
#          [ 0.0588,  0.0588,  0.0588,  ..., -0.2549, -0.2549, -0.2549],
#          [ 0.0588,  0.0588,  0.0588,  ..., -0.2549, -0.2549, -0.2549],
#          [ 0.0588,  0.0588,  0.0588,  ..., -0.2549, -0.2549, -0.2549]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[ 0.7412,  0.7412,  0.7412,  ...,  0.8510,  0.8510,  0.8510],
#          [ 0.7412,  0.7412,  0.7412,  ...,  0.8510,  0.8510,  0.8510],
#          [ 0.7412,  0.7412,  0.7412,  ...,  0.8510,  0.8510,  0.8510],
#          ...,
#          [-0.3490, -0.3490, -0.3490,  ..., -0.4353, -0.4353, -0.4353],
#          [-0.3490, -0.3490, -0.3490,  ..., -0.4353, -0.4353, -0.4353],
#          [-0.3490, -0.3490, -0.3490,  ..., -0.4353, -0.4353, -0.4353]],
#
#         [[ 0.9843,  0.9843,  0.9843,  ...,  0.9922,  0.9922,  0.9922],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.9922,  0.9922,  0.9922],
#          [ 0.9843,  0.9843,  0.9843,  ...,  0.9922,  0.9922,  0.9922],
#          ...,
#          [-0.4431, -0.4431, -0.4431,  ..., -0.5686, -0.5686, -0.5686],
#          [-0.4431, -0.4431, -0.4431,  ..., -0.5686, -0.5686, -0.5686],
#          [-0.4431, -0.4431, -0.4431,  ..., -0.5686, -0.5686, -0.5686]],
#
#         [[ 0.9922,  0.9922,  0.9922,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.9922,  0.9922,  0.9922,  ...,  1.0000,  1.0000,  1.0000],
#          [ 0.9922,  0.9922,  0.9922,  ...,  1.0000,  1.0000,  1.0000],
#          ...,
#          [-0.5216, -0.5216, -0.5216,  ..., -0.6627, -0.6627, -0.6627],
#          [-0.5216, -0.5216, -0.5216,  ..., -0.6627, -0.6627, -0.6627],
#          [-0.5216, -0.5216, -0.5216,  ..., -0.6627, -0.6627, -0.6627]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#          [ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#          [ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#          ...,
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196],
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196],
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196]],
#
#         [[ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#          [ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#          [ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#          ...,
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353],
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353],
#          [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353]],
#
#         [[ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#          [ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#          [ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#          ...,
#          [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745],
#          [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745],
#          [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#          [-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#          [-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#          ...,
#          [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588],
#          [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588],
#          [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588]],
#
#         [[-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#          [-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#          [-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#          ...,
#          [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078],
#          [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078],
#          [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078]],
#
#         [[-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#          [-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#          [-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#          ...,
#          [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294],
#          [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294],
#          [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294]]])
# torch.Size([3, 224, 224])
# ---------
# tensor([[[-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#          [-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#          [-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#          ...,
#          [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902],
#          [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902],
#          [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902]],
#
#         [[-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#          [-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#          [-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#          ...,
#          [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275],
#          [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275],
#          [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275]],
#
#         [[-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#          [-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#          [-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#          ...,
#          [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098],
#          [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098],
#          [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098]]])
# torch.Size([3, 224, 224])
# ---------
# tensor(8)
# -------
# tensor(3)
# -------
# tensor(5)
# -------
# tensor(6)
# -------
# tensor(2)
# -------
# tensor(5)
# -------
# tensor(1)
# -------
# tensor(1)
# -------
# {'pixel_values': tensor([[[[-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#           [-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#           [-0.6706, -0.6706, -0.6706,  ..., -0.6392, -0.6392, -0.6392],
#           ...,
#           [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333],
#           [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333],
#           [-0.4510, -0.4510, -0.4510,  ..., -0.3333, -0.3333, -0.3333]],
#
#          [[-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#           [-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#           [-0.7020, -0.7020, -0.7020,  ..., -0.5686, -0.5686, -0.5686],
#           ...,
#           [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196],
#           [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196],
#           [-0.1765, -0.1765, -0.1765,  ..., -0.0196, -0.0196, -0.0196]],
#
#          [[-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#           [-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#           [-0.9373, -0.9373, -0.9373,  ..., -0.5922, -0.5922, -0.5922],
#           ...,
#           [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843],
#           [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843],
#           [-0.0196, -0.0196, -0.0196,  ...,  0.1843,  0.1843,  0.1843]]],
#
#
#         [[[ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#           [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#           [ 0.9922,  0.9922,  0.9922,  ...,  0.9765,  0.9765,  0.9765],
#           ...,
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529],
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529],
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.5529,  0.5529,  0.5529]],
#
#          [[ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#           [ 0.9843,  0.9843,  0.9843,  ...,  0.9843,  0.9843,  0.9843],
#           ...,
#           [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588],
#           [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588],
#           [ 0.9765,  0.9765,  0.9765,  ..., -0.0588, -0.0588, -0.0588]],
#
#          [[ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#           [ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#           [ 0.9922,  0.9922,  0.9922,  ...,  0.9608,  0.9608,  0.9608],
#           ...,
#           [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824],
#           [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824],
#           [ 0.9843,  0.9843,  0.9843,  ..., -0.0824, -0.0824, -0.0824]]],
#
#
#         [[[-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.5373, -0.5373, -0.5373],
#           ...,
#           [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333],
#           [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333],
#           [-0.1294, -0.1294, -0.1294,  ..., -0.7333, -0.7333, -0.7333]],
#
#          [[-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.4196, -0.4196, -0.4196],
#           ...,
#           [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647],
#           [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647],
#           [-0.5765, -0.5765, -0.5765,  ..., -0.7647, -0.7647, -0.7647]],
#
#          [[-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#           [-0.9529, -0.9529, -0.9529,  ..., -0.2471, -0.2471, -0.2471],
#           ...,
#           [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647],
#           [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647],
#           [-0.7333, -0.7333, -0.7333,  ..., -0.7647, -0.7647, -0.7647]]],
#
#
#         ...,
#
#
#         [[[ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#           [ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#           [ 0.2549,  0.2549,  0.2549,  ..., -0.5686, -0.5686, -0.5686],
#           ...,
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196],
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196],
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0196,  0.0196,  0.0196]],
#
#          [[ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#           [ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#           [ 0.3176,  0.3176,  0.3176,  ..., -0.5608, -0.5608, -0.5608],
#           ...,
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353],
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353],
#           [ 0.1608,  0.1608,  0.1608,  ...,  0.0353,  0.0353,  0.0353]],
#
#          [[ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#           [ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#           [ 0.2314,  0.2314,  0.2314,  ..., -0.5294, -0.5294, -0.5294],
#           ...,
#           [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745],
#           [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745],
#           [ 0.0431,  0.0431,  0.0431,  ...,  0.0745,  0.0745,  0.0745]]],
#
#
#         [[[-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#           [-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#           [-0.8824, -0.8824, -0.8824,  ...,  0.9686,  0.9686,  0.9686],
#           ...,
#           [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588],
#           [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588],
#           [-0.7490, -0.7490, -0.7490,  ..., -0.4588, -0.4588, -0.4588]],
#
#          [[-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#           [-1.0000, -1.0000, -1.0000,  ...,  0.9608,  0.9608,  0.9608],
#           ...,
#           [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078],
#           [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078],
#           [-0.9059, -0.9059, -0.9059,  ..., -0.6078, -0.6078, -0.6078]],
#
#          [[-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#           [-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#           [-0.9843, -0.9843, -0.9843,  ...,  0.8824,  0.8824,  0.8824],
#           ...,
#           [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294],
#           [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294],
#           [-0.9294, -0.9294, -0.9294,  ..., -0.5294, -0.5294, -0.5294]]],
#
#
#         [[[-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#           [-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#           [-0.0039, -0.0039, -0.0039,  ...,  0.4039,  0.4039,  0.4039],
#           ...,
#           [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902],
#           [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902],
#           [-0.5922, -0.5922, -0.5922,  ...,  0.0902,  0.0902,  0.0902]],
#
#          [[-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#           [-1.0000, -1.0000, -1.0000,  ..., -0.7412, -0.7412, -0.7412],
#           ...,
#           [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275],
#           [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275],
#           [-0.5686, -0.5686, -0.5686,  ..., -0.4275, -0.4275, -0.4275]],
#
#          [[-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#           [-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#           [-0.7569, -0.7569, -0.7569,  ..., -0.5529, -0.5529, -0.5529],
#           ...,
#           [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098],
#           [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098],
#           [-0.5137, -0.5137, -0.5137,  ..., -0.3098, -0.3098, -0.3098]]]])}
# Inputs -------
# torch.Size([8, 3, 224, 224])

# %%
from transformers import ViTForImageClassification, ViTFeatureExtractor, ViTImageProcessor
from torch.optim import AdamW
import torch.nn as nn

model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k', num_labels=10)
model.to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=5e-5)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for epoch in range(1):  # Example: 3 epochs
    model.train()
    for batch in train_loader:        
        inputs = {k: v.to(device) for k, v in batch.items() if k != 'labels'}
        # inputs = batch['pixel_values'].to(device)
        labels = batch['labels'].to(device)
        optimizer.zero_grad()
        outputs = model(pixel_values = inputs['pixel_values'])
        
        loss = loss_fn(outputs.logits, labels)
        loss.backward()
        optimizer.step()
        print(f"Batch {epoch}, Loss: {loss.item()}")
    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 8
#       6 labels = batch['labels'].to(device)
#       7 optimizer.zero_grad()
# ----> 8 outputs = model(pixel_values = inputs['pixel_values'])
#      10 loss = loss_fn(outputs.logits, labels)
#      11 loss.backward()
#
# IndexError: too many indices for tensor of dimension 4
